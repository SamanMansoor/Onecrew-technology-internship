# %% [markdown]
# Load Data

# %%
import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv('/content/Sales Data.csv')

df
# Out:
#        Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 0               0    295665        Macbook Pro Laptop               1.0
# 1               1    295666        LG Washing Machine               1.0
# 2               2    295667      USB-C Charging Cable               1.0
# 3               3    295668          27in FHD Monitor               1.0
# 4               4    295669      USB-C Charging Cable               1.0
# ...           ...       ...                       ...               ...
# 60740        5502    167258      USB-C Charging Cable               1.0
# 60741        5503    167259  Lightning Charging Cable               1.0
# 60742        5504    167260  Apple Airpods Headphones               1.0
# 60743        5505    167261              Google Phone               1.0
# 60744        5506    167261                     USB-C               NaN
#
#        Price Each           Order Date  \
# 0         1700.00  2019-12-30 00:01:00
# 1          600.00  2019-12-29 07:03:00
# 2           11.95  2019-12-12 18:21:00
# 3          149.99  2019-12-22 15:13:00
# 4           11.95  2019-12-18 12:38:00
# ...           ...                  ...
# 60740       11.95  2019-03-28 13:20:00
# 60741       14.95  2019-03-02 07:03:00
# 60742      150.00  2019-03-22 21:25:00
# 60743      600.00  2019-03-22 14:42:00
# 60744         NaN                  NaN
#
#                                  Purchase Address  Month    Sales  \
# 0          136 Church St, New York City, NY 10001   12.0  1700.00
# 1             562 2nd St, New York City, NY 10001   12.0   600.00
# 2            277 Main St, New York City, NY 10001   12.0    11.95
# 3             410 6th St, San Francisco, CA 94016   12.0   149.99
# 4                   43 Hill St, Atlanta, GA 30301   12.0    11.95
# ...                                           ...    ...      ...
# 60740  520 Washington St, San Francisco, CA 94016    3.0    11.95
# 60741           678 8th St, Los Angeles, CA 90001    3.0    14.95
# 60742             431 Ridge St, Seattle, WA 98101    3.0   150.00
# 60743        900 West St, New York City, NY 10001    3.0   600.00
# 60744                                         NaN    NaN      NaN
#
#                  City  Hour
# 0       New York City   0.0
# 1       New York City   7.0
# 2       New York City  18.0
# 3       San Francisco  15.0
# 4             Atlanta  12.0
# ...               ...   ...
# 60740   San Francisco  13.0
# 60741     Los Angeles   7.0
# 60742         Seattle  21.0
# 60743   New York City  14.0
# 60744             NaN   NaN
#
# [60745 rows x 11 columns]

# %% [markdown]
# # **Data Inspection**

# %%
print("Number of rows and columns:", df.shape)
# Out:
# Number of rows and columns: (60745, 11)

# %%
print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop               1.0     1700.00
# 1           1    295666    LG Washing Machine               1.0      600.00
# 2           2    295667  USB-C Charging Cable               1.0       11.95
# 3           3    295668      27in FHD Monitor               1.0      149.99
# 4           4    295669  USB-C Charging Cable               1.0       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001   12.0
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   12.0
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001   12.0
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   12.0
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301   12.0
#
#      Sales            City  Hour
# 0  1700.00   New York City   0.0
# 1   600.00   New York City   7.0
# 2    11.95   New York City  18.0
# 3   149.99   San Francisco  15.0
# 4    11.95         Atlanta  12.0

# %%
print("Data info:")
print(df.info())
# Out:
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60745 entries, 0 to 60744
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        60745 non-null  int64
#  1   Order ID          60745 non-null  int64
#  2   Product           60745 non-null  object
#  3   Quantity Ordered  60744 non-null  float64
#  4   Price Each        60744 non-null  float64
#  5   Order Date        60744 non-null  object
#  6   Purchase Address  60744 non-null  object
#  7   Month             60744 non-null  float64
#  8   Sales             60744 non-null  float64
#  9   City              60744 non-null  object
#  10  Hour              60744 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 5.1+ MB
# None

# %% [markdown]
# # **Data Cleaning**

# %%
#Check Missing Values

print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    1
# Price Each          1
# Order Date          1
# Purchase Address    1
# Month               1
# Sales               1
# City                1
# Hour                1
# dtype: int64

# %%
#Check duplicate record
print("Number of duplicate records:", df.duplicated().sum())
# Out:
# Number of duplicate records: 0

# %%
df = df.drop_duplicates()
df
# Out:
#        Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 0               0    295665        Macbook Pro Laptop               1.0
# 1               1    295666        LG Washing Machine               1.0
# 2               2    295667      USB-C Charging Cable               1.0
# 3               3    295668          27in FHD Monitor               1.0
# 4               4    295669      USB-C Charging Cable               1.0
# ...           ...       ...                       ...               ...
# 60740        5502    167258      USB-C Charging Cable               1.0
# 60741        5503    167259  Lightning Charging Cable               1.0
# 60742        5504    167260  Apple Airpods Headphones               1.0
# 60743        5505    167261              Google Phone               1.0
# 60744        5506    167261                     USB-C               NaN
#
#        Price Each           Order Date  \
# 0         1700.00  2019-12-30 00:01:00
# 1          600.00  2019-12-29 07:03:00
# 2           11.95  2019-12-12 18:21:00
# 3          149.99  2019-12-22 15:13:00
# 4           11.95  2019-12-18 12:38:00
# ...           ...                  ...
# 60740       11.95  2019-03-28 13:20:00
# 60741       14.95  2019-03-02 07:03:00
# 60742      150.00  2019-03-22 21:25:00
# 60743      600.00  2019-03-22 14:42:00
# 60744         NaN                  NaN
#
#                                  Purchase Address  Month    Sales  \
# 0          136 Church St, New York City, NY 10001   12.0  1700.00
# 1             562 2nd St, New York City, NY 10001   12.0   600.00
# 2            277 Main St, New York City, NY 10001   12.0    11.95
# 3             410 6th St, San Francisco, CA 94016   12.0   149.99
# 4                   43 Hill St, Atlanta, GA 30301   12.0    11.95
# ...                                           ...    ...      ...
# 60740  520 Washington St, San Francisco, CA 94016    3.0    11.95
# 60741           678 8th St, Los Angeles, CA 90001    3.0    14.95
# 60742             431 Ridge St, Seattle, WA 98101    3.0   150.00
# 60743        900 West St, New York City, NY 10001    3.0   600.00
# 60744                                         NaN    NaN      NaN
#
#                  City  Hour
# 0       New York City   0.0
# 1       New York City   7.0
# 2       New York City  18.0
# 3       San Francisco  15.0
# 4             Atlanta  12.0
# ...               ...   ...
# 60740   San Francisco  13.0
# 60741     Los Angeles   7.0
# 60742         Seattle  21.0
# 60743   New York City  14.0
# 60744             NaN   NaN
#
# [60745 rows x 11 columns]

# %% [markdown]
# # **Data Analysis and Visualization**

# %%
print("Summary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#          Unnamed: 0       Order ID  Quantity Ordered    Price Each  \
# count  60745.000000   60745.000000      60744.000000  60744.000000
# mean    9369.862343  228045.392263          1.124095    184.035300
# std     6563.268207   67575.450927          0.438777    330.913349
# min        0.000000  150502.000000          1.000000      2.990000
# 25%     3816.000000  165066.000000          1.000000     11.950000
# 50%     8338.000000  188925.000000          1.000000     14.950000
# 75%    14122.000000  305056.000000          1.000000    150.000000
# max    25116.000000  319670.000000          7.000000   1700.000000
#
#               Month         Sales          Hour
# count  60744.000000  60744.000000  60744.000000
# mean       6.800919    185.122266     14.387907
# std        4.396798    331.217748      5.421358
# min        1.000000      2.990000      0.000000
# 25%        3.000000     11.950000     11.000000
# 50%        4.000000     14.950000     15.000000
# 75%       12.000000    150.000000     19.000000
# max       12.000000   3400.000000     23.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['Sales'], bins=20)
plt.xlabel('Sales')
plt.ylabel(' Price Each')
plt.title('Histogram of Sales')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df['Sales'], df['Quantity Ordered'])
plt.xlabel('Numeric Column 1')
plt.ylabel('Numeric Column 2')
plt.title('Scatter Plot between Numeric Column 1 and Numeric Column 2')
plt.show()
